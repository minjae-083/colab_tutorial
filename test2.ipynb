# %% [markdown]
# <a href="https://colab.research.google.com/github/minjae-083/colab_tutorial/blob/main/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# 추후에 이상치, 결측치 처리 과정을 추가할 수 있도록 하자

# %% [markdown]
# # 나이 - 생존율

# %%
# 나이가 어릴수록 생존율이 높은가?

df = sb.load_dataset('titanic')
bins = range(0, 101, 10)
labels = [f"{i}~{i+9}" for i in bins[:-1]]
df['age_group'] = pd.cut(df['age'], bins=bins, right=False, labels=labels)

df.groupby('age_group')['survived'].mean().plot(kind='bar')

plt.title('Age-Survived')
plt.xlabel('Age')
plt.ylabel('Survived')
plt.show()
# Out:
# <ipython-input-15-24c0efb28ce7>:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['survived'].mean().plot(kind='bar')

# %% [markdown]
# # 선실 등급 - 요금

# %%
# 선실 등급이 높을수록 요금을 더 많이 냈는가?

df = sb.load_dataset('titanic')

df.groupby('pclass')['fare'].mean().plot(kind='bar')

plt.title('Pclass-Fare')
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# # 탑승 항구 - 생존율

# %%
# 탑승 항구별로 생존율 차이가 있는가?

df = sb.load_dataset('titanic')

df.groupby('embarked')['survived'].mean().plot(kind='bar')

plt.title('Embark-Survived')
plt.xlabel('Embark')
plt.ylabel('Survived')
# Out:
# Text(0, 0.5, 'Survived')
